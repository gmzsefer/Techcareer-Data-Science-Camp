# %%
# Ödev 1: Kendini Tanıtma
ad = "Gamze Sefer"
bölüm = "Bilgisayar Mühendisliği"
sınıf = 4
yaş = 22
ortalama = 2.50

print(f"Merhaba, ben {ad}. {bölüm} {sınıf}. sınıf öğrencisiyim. Yaşım {yaş} ve ortalamam {ortalama}.")
# Out:
# Merhaba, ben Gamze Sefer. Bilgisayar Mühendisliği 4. sınıf öğrencisiyim. Yaşım 22 ve ortalamam 2.5.
